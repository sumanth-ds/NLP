# %%
#!pip install googletrans==4.0.0rc1

# !pip install deep-translator

# %%
from deep_translator import GoogleTranslator

# %%
translate = GoogleTranslator()
text = 'ईरान ने \'टाइमिंग\' के गेम में इजरायल को फंसाया! मिसाइल हमले के पलटवार पर साइलेंस के पीछे ये कारण तो नहीं'

# %%
english =  GoogleTranslator(src = 'hi' , dest= 'en').translate(text)

print('Original Text : ', text )
print('Translate Text : ', english)
# Out:
# Original Text :  ईरान ने 'टाइमिंग' के गेम में इजरायल को फंसाया! मिसाइल हमले के पलटवार पर साइलेंस के पीछे ये कारण तो नहीं
# Translate Text :  Iran trapped Israel in a game of 'timing'! Is this the reason behind the silence on the retaliation of the missile attack?

# %%
Iran implicated Israel in 'Timing' game!This is not the reason behind the silence on the retaliation of the missile attack

# %%
from googletrans import Translator

# %%
translate = Translator()
text = 'ईरान ने \'टाइमिंग\' के गेम में इजरायल को फंसाया! मिसाइल हमले के पलटवार पर साइलेंस के पीछे ये कारण तो नहीं'

# %%
english =  translate.translate(text , src = 'hi' , dest= 'en').text

print('Original Text : ', text )
print('Translate Text : ', englist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 english =  translate.translate(text , src = 'hi' , dest= 'en').text
#       3 print('Original Text : ', text )
#       4 print('Translate Text : ', englist)
#
# File ~\anaconda3\Lib\site-packages\googletrans\client.py:182, in Translator.translate(self, text, dest, src, **kwargs)
#     179     return result
#     181 origin = text
# --> 182 data = self._translate(text, dest, src, kwargs)
#     184 # this code will be updated when the format is changed.
#     185 translated = ''.join([d[0] if d[0] else '' for d in data[0]])
#
# File ~\anaconda3\Lib\site-packages\googletrans\client.py:78, in Translator._translate(self, text, dest, src, override)
#      77 def _translate(self, text, dest, src, override):
# ---> 78     token = self.token_acquirer.do(text)
# ...

# %%
# !pip uninstall googletrans
# Out:
# ^C

# %% [markdown]
# # TEXT TO SPEAK

# %%
# !pip install gtts

# %%
from gtts import gTTS
test =  gTTS(english, lang = 'en')
test.save('translated_news_hindi_to_english.mp3')

# %% [markdown]
# # SPeach to text

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/32.8 MB 316.6 kB/s eta 0:01:43
#     --------------------------------------- 0.5/32.8 MB 316.6 kB/s eta 0:01:43
#     --------------------------------------- 0.5/32.8 MB 316.6 kB/s eta 0:01:43
# ...

# %%
! pip install pyaudio

# %%
import speech_recognition as sr
import pyaudio

# %%
recognise = sr.Recognizer()
with sr.Microphone () as source:
    print("Speak something ..............")
    audio = recognise.listen(source)
try:
    text =  recognise.recognize_google(audio)
    print("Your are saying......", text)
except sr.UnkownValueError:
    print('Your are not adiable ...')
except  sr.RequestError:
    print('still not luck...')
# Out:
# Speak something ..............
# Your are saying...... using laptop
